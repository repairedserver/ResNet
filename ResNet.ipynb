# %% [markdown]
# <a href="https://colab.research.google.com/github/repairedserver/ResNet/blob/main/ResNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torchvision
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
from main import ResNet18, ResNet34, ResNet50, ResNet101, ResNet152
import os
import torchvision.models as models

# %%
def lr_scheduler(optimizer, epoch):
    lr = learning_rate
    if epoch >= 50:
        lr /= 10
    if epoch >= 100:
        lr /= 10
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr
        
def init_weights(m):
    if isinstance(m, nn.Linear):
        torch.nn.init.xavier_uniform(m.weight)
        m.bias.data.fill_(0.01)

# %%
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
])

train_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train)
test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_test)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=256, shuffle=True, num_workers=8)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=256, shuffle=False, num_workers=8)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:563: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
model = ResNet50()

# %%
model.apply(init_weights)
model = model.to(device)
# Out:
# <ipython-input-5-92e49fc29636>:12: UserWarning: nn.init.xavier_uniform is now deprecated in favor of nn.init.xavier_uniform_.
#   torch.nn.init.xavier_uniform(m.weight)

# %%
learning_rate = 0.1
num_epoch = 150
model_name = 'model.pth'

loss_fn = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=learning_rate, momentum=0.9, weight_decay=0.0001)

train_loss = 0
valid_loss = 0
correct = 0
total_cnt = 0
best_acc = 0

# %%
for epoch in range(num_epoch):
    print(f"====== { epoch+1} epoch of { num_epoch } ======")
    model.train()
    lr_scheduler(optimizer, epoch)
    train_loss = 0
    valid_loss = 0
    correct = 0
    total_cnt = 0

    for step, batch in enumerate(train_loader):
        batch[0], batch[1] = batch[0].to(device), batch[1].to(device)
        optimizer.zero_grad()
        
        logits = model(batch[0])
        loss = loss_fn(logits, batch[1])
        loss.backward()
        
        optimizer.step()
        train_loss += loss.item()
        _, predict = logits.max(1)
        
        total_cnt += batch[1].size(0)
        correct +=  predict.eq(batch[1]).sum().item()
        
        if step % 100 == 0 and step != 0:
            print(f"\n====== { step } Step of { len(train_loader) } ======")
            print(f"Train Accuracy : { correct / total_cnt }")
            print(f"Train Loss : { loss.item() / batch[1].size(0) }")
            
    correct = 0
    total_cnt = 0
    
    with torch.no_grad():
        model.eval()
        for step, batch in enumerate(test_loader):
            batch[0], batch[1] = batch[0].to(device), batch[1].to(device)
            total_cnt += batch[1].size(0)
            logits = model(batch[0])
            valid_loss += loss_fn(logits, batch[1])
            _, predict = logits.max(1)
            correct += predict.eq(batch[1]).sum().item()
        valid_acc = correct / total_cnt
        print(f"\nValid Accuracy : { valid_acc }")    
        print(f"Valid Loss : { valid_loss / total_cnt }")

        if(valid_acc > best_acc):
            best_acc = valid_acc
            torch.save(model, model_name)
            print("Model Saved!")
# Out:
# ====== 1 epoch of 150 ======
# /usr/local/lib/python3.8/dist-packages/torch/utils/data/dataloader.py:563: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# ====== 100 Step of 196 ======
# Train Accuracy : 0.13613861386138615
# Train Loss : 0.0091056227684021
#
# Valid Accuracy : 0.1587
# Valid Loss : 0.011182684451341629
# Model Saved!
# ====== 2 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.18193069306930693
# Train Loss : 0.008575672283768654
#
# Valid Accuracy : 0.2157
# Valid Loss : 0.05970612168312073
# Model Saved!
# ====== 3 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.23352413366336633
# Train Loss : 0.007505644112825394
#
# Valid Accuracy : 0.2869
# Valid Loss : 0.00885414145886898
# Model Saved!
# ====== 4 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.2863165222772277
# Train Loss : 0.007537904195487499
#
# Valid Accuracy : 0.3368
# Valid Loss : 0.008145949803292751
# Model Saved!
# ====== 5 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.31764387376237624
# Train Loss : 0.007209503557533026
#
# Valid Accuracy : 0.3571
# Valid Loss : 0.007333721965551376
# Model Saved!
# ====== 6 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.3370590965346535
# Train Loss : 0.006919067353010178
#
# Valid Accuracy : 0.3606
# Valid Loss : 0.006981063634157181
# Model Saved!
# ====== 7 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.34924195544554454
# Train Loss : 0.006870843470096588
#
# Valid Accuracy : 0.3977
# Valid Loss : 0.006675952114164829
# Model Saved!
# ====== 8 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.3760829207920792
# Train Loss : 0.0066923717968165874
#
# Valid Accuracy : 0.4039
# Valid Loss : 0.006557449232786894
# Model Saved!
# ====== 9 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.38791769801980197
# Train Loss : 0.006487470120191574
#
# Valid Accuracy : 0.4078
# Valid Loss : 0.0065257353708148
# Model Saved!
# ====== 10 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.3987855816831683
# Train Loss : 0.00672311894595623
#
# Valid Accuracy : 0.4263
# Valid Loss : 0.006347269285470247
# Model Saved!
# ====== 11 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.41007889851485146
# Train Loss : 0.006386696361005306
#
# Valid Accuracy : 0.4475
# Valid Loss : 0.006097405683249235
# Model Saved!
# ====== 12 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.4199412128712871
# Train Loss : 0.00640305457636714
#
# Valid Accuracy : 0.4575
# Valid Loss : 0.005994741804897785
# Model Saved!
# ====== 13 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.4277923886138614
# Train Loss : 0.006386928725987673
#
# Valid Accuracy : 0.4683
# Valid Loss : 0.005870243068784475
# Model Saved!
# ====== 14 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.44832920792079206
# Train Loss : 0.006310208700597286
#
# Valid Accuracy : 0.4658
# Valid Loss : 0.0058955783024430275
# ====== 15 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.451771349009901
# Train Loss : 0.005680356174707413
#
# Valid Accuracy : 0.4922
# Valid Loss : 0.005629143211990595
# Model Saved!
# ====== 16 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.4583462252475248
# Train Loss : 0.005798098631203175
#
# Valid Accuracy : 0.4973
# Valid Loss : 0.005518572870641947
# Model Saved!
# ====== 17 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.4713799504950495
# Train Loss : 0.005839369725435972
#
# Valid Accuracy : 0.509
# Valid Loss : 0.0054524606093764305
# Model Saved!
# ====== 18 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.4791537747524752
# Train Loss : 0.0052582500502467155
#
# Valid Accuracy : 0.5211
# Valid Loss : 0.005370146129280329
# Model Saved!
# ====== 19 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.4909112004950495
# Train Loss : 0.0052977269515395164
#
# Valid Accuracy : 0.5285
# Valid Loss : 0.005246696528047323
# Model Saved!
# ====== 20 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.4915300123762376
# Train Loss : 0.005888675339519978
#
# Valid Accuracy : 0.5162
# Valid Loss : 0.005719597451388836
# ====== 21 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.5056853341584159
# Train Loss : 0.005523785017430782
#
# Valid Accuracy : 0.52
# Valid Loss : 0.005273883696645498
# ====== 22 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.5102877475247525
# Train Loss : 0.005017522256821394
#
# Valid Accuracy : 0.5338
# Valid Loss : 0.005113883875310421
# Model Saved!
# ====== 23 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.5140779702970297
# Train Loss : 0.005138047970831394
#
# Valid Accuracy : 0.5333
# Valid Loss : 0.0051121641881763935
# ====== 24 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.5289294554455446
# Train Loss : 0.005234961863607168
#
# Valid Accuracy : 0.548
# Valid Loss : 0.005075222812592983
# Model Saved!
# ====== 25 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.5335318688118812
# Train Loss : 0.0049887835048139095
#
# Valid Accuracy : 0.5339
# Valid Loss : 0.00516125001013279
# ====== 26 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.5418858292079208
# Train Loss : 0.004712037742137909
#
# Valid Accuracy : 0.5487
# Valid Loss : 0.00506606325507164
# Model Saved!
# ====== 27 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.5460241336633663
# Train Loss : 0.0051653278060257435
#
# Valid Accuracy : 0.5358
# Valid Loss : 0.00542100565508008
# ====== 28 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.5539526608910891
# Train Loss : 0.00471029756590724
#
# Valid Accuracy : 0.5632
# Valid Loss : 0.004845174495130777
# Model Saved!
# ====== 29 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.5587097772277227
# Train Loss : 0.004409944172948599
#
# Valid Accuracy : 0.5559
# Valid Loss : 0.005020655691623688
# ====== 30 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.5642790841584159
# Train Loss : 0.005213539116084576
#
# Valid Accuracy : 0.5819
# Valid Loss : 0.004674263298511505
# Model Saved!
# ====== 31 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.5701964727722773
# Train Loss : 0.004485315643250942
#
# Valid Accuracy : 0.5761
# Valid Loss : 0.004703522194176912
# ====== 32 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.5823019801980198
# Train Loss : 0.004814580548554659
#
# Valid Accuracy : 0.5853
# Valid Loss : 0.004587747156620026
# Model Saved!
# ====== 33 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.5811803836633663
# Train Loss : 0.004522890318185091
#
# Valid Accuracy : 0.599
# Valid Loss : 0.00448919041082263
# Model Saved!
# ====== 34 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.5893022896039604
# Train Loss : 0.004507743753492832
#
# Valid Accuracy : 0.6093
# Valid Loss : 0.004378365818411112
# Model Saved!
# ====== 35 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.6004409034653465
# Train Loss : 0.00453184125944972
#
# Valid Accuracy : 0.5997
# Valid Loss : 0.004563787952065468
# ====== 36 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.6087948638613861
# Train Loss : 0.004157661460340023
#
# Valid Accuracy : 0.6137
# Valid Loss : 0.004381822422146797
# Model Saved!
# ====== 37 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.6133972772277227
# Train Loss : 0.004783728159964085
#
# Valid Accuracy : 0.6243
# Valid Loss : 0.004239877685904503
# Model Saved!
# ====== 38 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.614634900990099
# Train Loss : 0.004315591417253017
#
# Valid Accuracy : 0.6158
# Valid Loss : 0.004317526705563068
# ====== 39 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.6236850247524752
# Train Loss : 0.004264238756150007
#
# Valid Accuracy : 0.5912
# Valid Loss : 0.004499650560319424
# ====== 40 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.6313814975247525
# Train Loss : 0.0038489040452986956
#
# Valid Accuracy : 0.6268
# Valid Loss : 0.004240630194544792
# Model Saved!
# ====== 41 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.6338954207920792
# Train Loss : 0.004063511732965708
#
# Valid Accuracy : 0.63
# Valid Loss : 0.004179387353360653
# Model Saved!
# ====== 42 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.6417079207920792
# Train Loss : 0.0038111654575914145
#
# Valid Accuracy : 0.6132
# Valid Loss : 0.0044210683554410934
# ====== 43 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.6489016089108911
# Train Loss : 0.0038820719346404076
#
# Valid Accuracy : 0.6429
# Valid Loss : 0.004058348946273327
# Model Saved!
# ====== 44 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.6570621905940595
# Train Loss : 0.003738733474165201
#
# Valid Accuracy : 0.6371
# Valid Loss : 0.004073471762239933
# ====== 45 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.6647973391089109
# Train Loss : 0.003974344115704298
#
# Valid Accuracy : 0.653
# Valid Loss : 0.003955204505473375
# Model Saved!
# ====== 46 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.6688969678217822
# Train Loss : 0.0036338719073683023
#
# Valid Accuracy : 0.6769
# Valid Loss : 0.0037214048206806183
# Model Saved!
# ====== 47 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.6764387376237624
# Train Loss : 0.0035020511131733656
#
# Valid Accuracy : 0.665
# Valid Loss : 0.003857265692204237
# ====== 48 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.6765934405940595
# Train Loss : 0.0037560591008514166
#
# Valid Accuracy : 0.6734
# Valid Loss : 0.003762956475839019
# ====== 49 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.6883508663366337
# Train Loss : 0.003187675727531314
#
# Valid Accuracy : 0.6885
# Valid Loss : 0.0037027059588581324
# Model Saved!
# ====== 50 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.6904780321782178
# Train Loss : 0.003679320216178894
#
# Valid Accuracy : 0.6888
# Valid Loss : 0.003594944253563881
# Model Saved!
# ====== 51 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.7288443688118812
# Train Loss : 0.0026804343797266483
#
# Valid Accuracy : 0.7228
# Valid Loss : 0.0032288026995956898
# Model Saved!
# ====== 52 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.7365408415841584
# Train Loss : 0.0031084585934877396
#
# Valid Accuracy : 0.7244
# Valid Loss : 0.0031969468109309673
# Model Saved!
# ====== 53 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.744740099009901
# Train Loss : 0.002809892175719142
#
# Valid Accuracy : 0.7259
# Valid Loss : 0.003231111913919449
# Model Saved!
# ====== 54 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.7462484529702971
# Train Loss : 0.0029167444445192814
#
# Valid Accuracy : 0.7284
# Valid Loss : 0.0031630899757146835
# Model Saved!
# ====== 55 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.7510055693069307
# Train Loss : 0.002609137911349535
#
# Valid Accuracy : 0.7313
# Valid Loss : 0.003167217131704092
# Model Saved!
# ====== 56 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.7532874381188119
# Train Loss : 0.0030418557580560446
#
# Valid Accuracy : 0.7275
# Valid Loss : 0.003212763462215662
# ====== 57 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.7512762995049505
# Train Loss : 0.002752783242613077
#
# Valid Accuracy : 0.7272
# Valid Loss : 0.0031794265378266573
# ====== 58 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.758856745049505
# Train Loss : 0.0028943803627043962
#
# Valid Accuracy : 0.7324
# Valid Loss : 0.00314759137108922
# Model Saved!
# ====== 59 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.7602877475247525
# Train Loss : 0.0025799924042075872
#
# Valid Accuracy : 0.7323
# Valid Loss : 0.0031445107888430357
# ====== 60 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.7610999381188119
# Train Loss : 0.002754042623564601
#
# Valid Accuracy : 0.7372
# Valid Loss : 0.0031106090173125267
# Model Saved!
# ====== 61 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.7614866955445545
# Train Loss : 0.002664528787136078
#
# Valid Accuracy : 0.734
# Valid Loss : 0.0031081675551831722
# ====== 62 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.7626469678217822
# Train Loss : 0.002622882602736354
#
# Valid Accuracy : 0.7349
# Valid Loss : 0.0030681148637086153
# ====== 63 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.7702274133663366
# Train Loss : 0.0027865124866366386
#
# Valid Accuracy : 0.737
# Valid Loss : 0.003099776105955243
# ====== 64 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.7691058168316832
# Train Loss : 0.0026948368176817894
#
# Valid Accuracy : 0.7362
# Valid Loss : 0.0030960889998823404
# ====== 65 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.7706528465346535
# Train Loss : 0.0028025428764522076
#
# Valid Accuracy : 0.7344
# Valid Loss : 0.003140525659546256
# ====== 66 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.7688737623762376
# Train Loss : 0.0022152888122946024
#
# Valid Accuracy : 0.7355
# Valid Loss : 0.003082084469497204
# ====== 67 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.7718517945544554
# Train Loss : 0.0033271233551204205
#
# Valid Accuracy : 0.7348
# Valid Loss : 0.003086355049163103
# ====== 68 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.7688737623762376
# Train Loss : 0.0029672025702893734
#
# Valid Accuracy : 0.7354
# Valid Loss : 0.0031332438811659813
# ====== 69 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.7783106435643564
# Train Loss : 0.0023540386464446783
#
# Valid Accuracy : 0.7365
# Valid Loss : 0.003102637594565749
# ====== 70 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.7773824257425742
# Train Loss : 0.002213673898950219
#
# Valid Accuracy : 0.7407
# Valid Loss : 0.0031129152048379183
# Model Saved!
# ====== 71 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.7789681311881188
# Train Loss : 0.002531127305701375
#
# Valid Accuracy : 0.7306
# Valid Loss : 0.003234687028452754
# ====== 72 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.7287670173267327
# Train Loss : 0.002597269369289279
#
# Valid Accuracy : 0.7331
# Valid Loss : 0.0031125557143241167
# ====== 73 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.766823948019802
# Train Loss : 0.00273093581199646
#
# Valid Accuracy : 0.7375
# Valid Loss : 0.0030731100123375654
# ====== 74 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.7755259900990099
# Train Loss : 0.0025470093823969364
#
# Valid Accuracy : 0.7379
# Valid Loss : 0.0030794667545706034
# ====== 75 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.7786587252475248
# Train Loss : 0.0026513871271163225
#
# Valid Accuracy : 0.7421
# Valid Loss : 0.003035096451640129
# Model Saved!
# ====== 76 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.7839186262376238
# Train Loss : 0.0022168285213410854
#
# Valid Accuracy : 0.7367
# Valid Loss : 0.003101278329268098
# ====== 77 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.782294245049505
# Train Loss : 0.0026962587144225836
#
# Valid Accuracy : 0.744
# Valid Loss : 0.0030636603478342295
# Model Saved!
# ====== 78 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.7833771658415841
# Train Loss : 0.0021002497524023056
#
# Valid Accuracy : 0.7415
# Valid Loss : 0.003037885529920459
# ====== 79 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.7875154702970297
# Train Loss : 0.002484876662492752
#
# Valid Accuracy : 0.7423
# Valid Loss : 0.0030321411322802305
# ====== 80 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.7889851485148515
# Train Loss : 0.0027487478218972683
#
# Valid Accuracy : 0.7414
# Valid Loss : 0.0030816406942903996
# ====== 81 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.7909962871287128
# Train Loss : 0.0020217422861605883
#
# Valid Accuracy : 0.7457
# Valid Loss : 0.00309505732730031
# Model Saved!
# ====== 82 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.7945931311881188
# Train Loss : 0.0026322240009903908
#
# Valid Accuracy : 0.743
# Valid Loss : 0.003076068125665188
# ====== 83 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.7964108910891089
# Train Loss : 0.0021815786603838205
#
# Valid Accuracy : 0.7391
# Valid Loss : 0.003157383995130658
# ====== 84 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.7971070544554455
# Train Loss : 0.0020954874344170094
#
# Valid Accuracy : 0.738
# Valid Loss : 0.0031382835004478693
# ====== 85 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.7883663366336634
# Train Loss : 0.0026726543437689543
#
# Valid Accuracy : 0.7434
# Valid Loss : 0.003107453929260373
# ====== 86 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.7941290222772277
# Train Loss : 0.0020737105514854193
#
# Valid Accuracy : 0.7426
# Valid Loss : 0.003062623320147395
# ====== 87 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.80078125
# Train Loss : 0.002499211812391877
#
# Valid Accuracy : 0.7449
# Valid Loss : 0.003040693700313568
# ====== 88 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.7991955445544554
# Train Loss : 0.0023750877007842064
#
# Valid Accuracy : 0.7391
# Valid Loss : 0.003081260249018669
# ====== 89 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.8009359529702971
# Train Loss : 0.002374461153522134
#
# Valid Accuracy : 0.7435
# Valid Loss : 0.003120686858892441
# ====== 90 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.804378094059406
# Train Loss : 0.0021711932495236397
#
# Valid Accuracy : 0.7443
# Valid Loss : 0.00307708908803761
# ====== 91 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.8072787747524752
# Train Loss : 0.0022840939927846193
#
# Valid Accuracy : 0.7441
# Valid Loss : 0.0030589839443564415
# ====== 92 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.7891398514851485
# Train Loss : 0.002239184221252799
#
# Valid Accuracy : 0.7388
# Valid Loss : 0.003202595515176654
# ====== 93 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.8053836633663366
# Train Loss : 0.0018820755649358034
#
# Valid Accuracy : 0.7423
# Valid Loss : 0.0031405887566506863
# ====== 94 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.7961014851485149
# Train Loss : 0.0019095310708507895
#
# Valid Accuracy : 0.7442
# Valid Loss : 0.003351108403876424
# ====== 95 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.8085550742574258
# Train Loss : 0.002396124415099621
#
# Valid Accuracy : 0.7413
# Valid Loss : 0.0032599216792732477
# ====== 96 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.8158261138613861
# Train Loss : 0.002154683228582144
#
# Valid Accuracy : 0.741
# Valid Loss : 0.003251434303820133
# ====== 97 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.8134282178217822
# Train Loss : 0.002321234904229641
#
# Valid Accuracy : 0.7422
# Valid Loss : 0.0032398379407823086
# ====== 98 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.815362004950495
# Train Loss : 0.0017171576619148254
#
# Valid Accuracy : 0.7428
# Valid Loss : 0.0033956440165638924
# ====== 99 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.8183400371287128
# Train Loss : 0.0023543823044747114
#
# Valid Accuracy : 0.7425
# Valid Loss : 0.0037045737262815237
# ====== 100 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.8203511757425742
# Train Loss : 0.002051060786470771
#
# Valid Accuracy : 0.742
# Valid Loss : 0.003390741301700473
# ====== 101 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.8335396039603961
# Train Loss : 0.0015775939682498574
#
# Valid Accuracy : 0.7505
# Valid Loss : 0.003174887504428625
# Model Saved!
# ====== 102 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.8307162747524752
# Train Loss : 0.002249718876555562
#
# Valid Accuracy : 0.752
# Valid Loss : 0.003206368535757065
# Model Saved!
# ====== 103 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.837291150990099
# Train Loss : 0.0017116002272814512
#
# Valid Accuracy : 0.7478
# Valid Loss : 0.003288569627329707
# ====== 104 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.838180693069307
# Train Loss : 0.0017400303622707725
#
# Valid Accuracy : 0.7468
# Valid Loss : 0.0038259627763181925
# ====== 105 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.8377165841584159
# Train Loss : 0.001797798671759665
#
# Valid Accuracy : 0.7467
# Valid Loss : 0.004118512850254774
# ====== 106 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.838799504950495
# Train Loss : 0.0017367276595905423
#
# Valid Accuracy : 0.7457
# Valid Loss : 0.004375134594738483
# ====== 107 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.8399984529702971
# Train Loss : 0.002048998838290572
#
# Valid Accuracy : 0.7483
# Valid Loss : 0.0034495836589485407
# ====== 108 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.8389155321782178
# Train Loss : 0.001624029828235507
#
# Valid Accuracy : 0.749
# Valid Loss : 0.0038008913397789
# ====== 109 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.8418935643564357
# Train Loss : 0.0015662352088838816
#
# Valid Accuracy : 0.7479
# Valid Loss : 0.0036642097402364016
# ====== 110 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.8384514232673267
# Train Loss : 0.00160182302352041
#
# Valid Accuracy : 0.7456
# Valid Loss : 0.003877612529322505
# ====== 111 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.8423189975247525
# Train Loss : 0.0017058587400242686
#
# Valid Accuracy : 0.7458
# Valid Loss : 0.0037402366288006306
# ====== 112 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.8398050742574258
# Train Loss : 0.0016869589453563094
#
# Valid Accuracy : 0.7455
# Valid Loss : 0.0036330122966319323
# ====== 113 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.8395730198019802
# Train Loss : 0.002039893064647913
#
# Valid Accuracy : 0.747
# Valid Loss : 0.003936558496206999
# ====== 114 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.8420482673267327
# Train Loss : 0.001392384059727192
#
# Valid Accuracy : 0.7485
# Valid Loss : 0.004202763084322214
# ====== 115 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.8481203589108911
# Train Loss : 0.0016172878677025437
#
# Valid Accuracy : 0.7485
# Valid Loss : 0.0036430994514375925
# ====== 116 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.8440207301980198
# Train Loss : 0.0017253917176276445
#
# Valid Accuracy : 0.7435
# Valid Loss : 0.00430441927164793
# ====== 117 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.8395730198019802
# Train Loss : 0.001657747896388173
#
# Valid Accuracy : 0.7487
# Valid Loss : 0.003652807790786028
# ====== 118 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.844059405940594
# Train Loss : 0.0017227391945198178
#
# Valid Accuracy : 0.7494
# Valid Loss : 0.0036591337993741035
# ====== 119 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.8487391707920792
# Train Loss : 0.0019511643331497908
#
# Valid Accuracy : 0.7502
# Valid Loss : 0.00334205967374146
# ====== 120 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.8440980816831684
# Train Loss : 0.0018094221595674753
#
# Valid Accuracy : 0.7459
# Valid Loss : 0.003521314822137356
# ====== 121 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.8475402227722773
# Train Loss : 0.001964989583939314
#
# Valid Accuracy : 0.7464
# Valid Loss : 0.0036793039180338383
# ====== 122 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.8446008663366337
# Train Loss : 0.0017610943177714944
#
# Valid Accuracy : 0.7463
# Valid Loss : 0.00391807034611702
# ====== 123 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.8470761138613861
# Train Loss : 0.001695694518275559
#
# Valid Accuracy : 0.7459
# Valid Loss : 0.00374900852330029
# ====== 124 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.8460318688118812
# Train Loss : 0.0015909294597804546
#
# Valid Accuracy : 0.747
# Valid Loss : 0.003876467002555728
# ====== 125 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.8466506806930693
# Train Loss : 0.0015450611244887114
#
# Valid Accuracy : 0.7497
# Valid Loss : 0.0033763605169951916
# ====== 126 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.8479269801980198
# Train Loss : 0.001824989914894104
#
# Valid Accuracy : 0.7504
# Valid Loss : 0.003407114651054144
# ====== 127 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.8482363861386139
# Train Loss : 0.0012307162396609783
#
# Valid Accuracy : 0.7485
# Valid Loss : 0.003468887647613883
# ====== 128 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.8510983910891089
# Train Loss : 0.0011913198977708817
#
# Valid Accuracy : 0.7496
# Valid Loss : 0.0035643302835524082
# ====== 129 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.8495126856435643
# Train Loss : 0.0018918683053925633
#
# Valid Accuracy : 0.749
# Valid Loss : 0.0033968512434512377
# ====== 130 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.849319306930693
# Train Loss : 0.001290876534767449
#
# Valid Accuracy : 0.7481
# Valid Loss : 0.0038500127848237753
# ====== 131 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.8525680693069307
# Train Loss : 0.001542561687529087
#
# Valid Accuracy : 0.7469
# Valid Loss : 0.003947444725781679
# ====== 132 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.8490485767326733
# Train Loss : 0.001388229546137154
#
# Valid Accuracy : 0.7493
# Valid Loss : 0.003549007698893547
# ====== 133 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.849319306930693
# Train Loss : 0.0014424525434151292
#
# Valid Accuracy : 0.7485
# Valid Loss : 0.0035220016725361347
# ====== 134 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.8477722772277227
# Train Loss : 0.00157727615442127
#
# Valid Accuracy : 0.748
# Valid Loss : 0.003471689997240901
# ====== 135 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.8514464727722773
# Train Loss : 0.0014928553719073534
#
# Valid Accuracy : 0.7445
# Valid Loss : 0.003946044947952032
# ====== 136 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.8521813118811881
# Train Loss : 0.0015757621731609106
#
# Valid Accuracy : 0.7479
# Valid Loss : 0.004160373006016016
# ====== 137 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.8509050123762376
# Train Loss : 0.0018424902809783816
#
# Valid Accuracy : 0.7432
# Valid Loss : 0.003844874445348978
# ====== 138 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.8503248762376238
# Train Loss : 0.001590538420714438
#
# Valid Accuracy : 0.7469
# Valid Loss : 0.004160533659160137
# ====== 139 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.8515625
# Train Loss : 0.0014588633785024285
#
# Valid Accuracy : 0.7506
# Valid Loss : 0.003291031578555703
# ====== 140 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.8539217202970297
# Train Loss : 0.0013098393101245165
#
# Valid Accuracy : 0.7441
# Valid Loss : 0.00406274339184165
# ====== 141 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.8549272896039604
# Train Loss : 0.0015081557212397456
#
# Valid Accuracy : 0.7469
# Valid Loss : 0.004326458089053631
# ====== 142 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.8525293935643564
# Train Loss : 0.0016401461325585842
#
# Valid Accuracy : 0.7458
# Valid Loss : 0.0039323619566857815
# ====== 143 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.8533802599009901
# Train Loss : 0.001707800547592342
#
# Valid Accuracy : 0.7478
# Valid Loss : 0.003513846779242158
# ====== 144 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.8563969678217822
# Train Loss : 0.0012441686121746898
#
# Valid Accuracy : 0.7499
# Valid Loss : 0.003359621623530984
# ====== 145 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.856512995049505
# Train Loss : 0.0019952605944126844
#
# Valid Accuracy : 0.7472
# Valid Loss : 0.0042604682967066765
# ====== 146 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.8545018564356436
# Train Loss : 0.001754882512614131
#
# Valid Accuracy : 0.7481
# Valid Loss : 0.003816485870629549
# ====== 147 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.8570931311881188
# Train Loss : 0.0017321802442893386
#
# Valid Accuracy : 0.747
# Valid Loss : 0.0038471126463264227
# ====== 148 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.8569771039603961
# Train Loss : 0.0014361663488671184
#
# Valid Accuracy : 0.7437
# Valid Loss : 0.003763037733733654
# ====== 149 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.8605352722772277
# Train Loss : 0.0015524592017754912
#
# Valid Accuracy : 0.7476
# Valid Loss : 0.00351944612339139
# ====== 150 epoch of 150 ======
#
# ====== 100 Step of 196 ======
# Train Accuracy : 0.8612314356435643
# Train Loss : 0.0016046888194978237
#
# Valid Accuracy : 0.7467
# Valid Loss : 0.003829057328402996
